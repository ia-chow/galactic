# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# from AST425 import *
# Out:
# 2025-04-26 11:11:48.272611: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-26 11:11:48.274218: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-26 11:11:48.280560: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-26 11:11:48.300407: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745680308.333123  117998 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745680308.343078  117998 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-26 11:11:48.376666: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#shape of VAE is 38, 100, 100, 2, 100, 100 38

# %%
plt.rcParams['axes.titlesize'] = 13
plt.rcParams['axes.labelsize'] = 13
plt.rcParams['xtick.labelsize'] = 11
plt.rcParams['ytick.labelsize'] = 11
plt.rcParams['figure.figsize'] = (12,8)
plt.rcParams['legend.fontsize'] = 13

# %% [markdown]
# Data preprocessing (same step for all methods):

# %%
data = pd.read_csv('../tsne_umap_tutorials/data/APOGEEDR17_GAIAEDR3_noflagfilter.csv', delimiter=',')

# data = pd.read_csv('APOGEEDR17_GAIAEDR3_noflagfilter.csv', delimiter=',')

# %%
# Spatial:
ra = data["RA"]   #APOGEE
dec = data["DEC"]   #APOGEE

# Identification:
apogee_ID = data["# APOGEE_ID_"]   #APOGEE
gaia_ID = data["GAIAEDR3_SOURCE_ID"]  # Gaia

# Kinematic:
parallax = data["GAIAEDR3_PARALLAX"]  # Gaia
pmra = data["GAIAEDR3_PMRA"]  # Gaia
pmra_err = data["GAIAEDR3_PMRA_ERROR"]  # Gaia
pmdec = data["GAIAEDR3_PMDEC"]  # Gaia
pmdec_err = data["GAIAEDR3_PMDEC_ERROR"]  # Gaia
RV = data["VHELIO_AVG"]   #APOGEE
RV_err = data["VERR"]   #APOGEE
#dist = data["dist"]   #APOGEE no dist in this dataset?
#dist_err = data["dist_err"]   #APOGEE
jr = data["jr"]   #APOGEE
jr_err = data["jr_err"]   #APOGEE
jz = data["jz"]   #APOGEE
jz_err = data["jz_err"]   #APOGEE
#jphi = data["jphi"]   #APOGEE no jphi in this dataset?
#jphi_err = data["jphi_err"]    #APOGEE

# # Spectral (useful for filtering):
TEFF_ERR = data["TEFF_ERR"]   #APOGEE
TEFF = data["TEFF"]   #APOGEE
LOGG_ERR = data["LOGG_ERR"]   #APOGEE
LOGG = data["LOGG"]   #APOGEE
SNR = data["SNR"]   #APOGEE
ASPCAPFLAG = data["ASPCAPFLAG"]
STARFLAG = data["STARFLAG"]

# # Chemical abundances from astroNN:
FE_H = data['FE_H'] 
C_FE = data['C_FE']
CI_FE = data['CI_FE']
N_FE = data['N_FE']
O_FE = data['O_FE']
MG_FE = data['MG_FE']
AL_FE = data['AL_FE']
SI_FE = data['SI_FE']
P_FE = data['P_FE']
S_FE = data['S_FE']
K_FE = data['K_FE']
CA_FE = data['CA_FE']
TI_FE = data['TI_FE']
TIII_FE = data['TIII_FE']
V_FE = data['V_FE']
CR_FE = data['CR_FE']
MN_FE = data['MN_FE']
CO_FE = data['CO_FE']
NI_FE = data['NI_FE']

# # Chemical abundance errors from astroNN:
FE_H_err = data["FE_H_ERR"] 
C_FE_err = data['C_FE_ERR']
CI_FE_err = data['CI_FE_ERR']
N_FE_err = data['N_FE_ERR']
O_FE_err = data['O_FE_ERR']
MG_FE_err = data['MG_FE_ERR']
AL_FE_err = data['AL_FE_ERR']
SI_FE_err = data['SI_FE_ERR']
P_FE_err = data['P_FE_ERR']
S_FE_err = data['S_FE_ERR']
K_FE_err = data['K_FE_ERR']
CA_FE_err = data['CA_FE_ERR']
TI_FE_err = data['TI_FE_ERR']
TIII_FE_err = data['TIII_FE_ERR']
V_FE_err = data['V_FE_ERR']
CR_FE_err = data['CR_FE_ERR']
MN_FE_err = data['MN_FE_ERR']
CO_FE_err = data['CO_FE_ERR']
NI_FE_err = data['NI_FE_ERR']

# # Number of stars in the initial sample of APOGEE DR16: 
print("There are {} stars in our initial sample".format(len(ra)))

cols = [ra, dec, apogee_ID, gaia_ID, parallax, pmra, pmra_err, pmdec, pmdec_err, RV, RV_err, #dist, dist_err,
         jr, jr_err,# jphi, jphi_err,
        jz, jz_err, TEFF, TEFF_ERR, LOGG, LOGG_ERR, SNR, ASPCAPFLAG, STARFLAG, FE_H, FE_H_err, C_FE, 
         C_FE_err, CI_FE, CI_FE_err, N_FE, N_FE_err, O_FE, O_FE_err, MG_FE, MG_FE_err, AL_FE, AL_FE_err, SI_FE,
         SI_FE_err, P_FE, P_FE_err, S_FE, S_FE_err, K_FE, K_FE_err, CA_FE, CA_FE_err, TI_FE, TI_FE_err, TIII_FE,
         TIII_FE_err, V_FE, V_FE_err, CR_FE, CR_FE_err, MN_FE, MN_FE_err, CO_FE, CO_FE_err, NI_FE, NI_FE_err]
# Out:
# There are 370060 stars in our initial sample

# %%
aspcapflags_filter = np.array(cols[20])==0
starflags_filter = np.array(cols[21])==0

filters = aspcapflags_filter*starflags_filter


filtered_data = []
for c in cols:
    a = np.array(c)[filters]
    filtered_data.append(a)
    
print("There are {} stars in our filtered sample".format(len(filtered_data[0])))
# Out:
# There are 144767 stars in our filtered sample

# %%
FE_H_filtered, C_FE_filtered, CI_FE_filtered = filtered_data[22], filtered_data[24], filtered_data[26]
N_FE_filtered, O_FE_filtered, MG_FE_filtered = filtered_data[28], filtered_data[30], filtered_data[32]
AL_FE_filtered, SI_FE_filtered, P_FE_filtered = filtered_data[34], filtered_data[36], filtered_data[38]
S_FE_filtered, K_FE_filtered, CA_FE_filtered = filtered_data[40], filtered_data[42], filtered_data[44]
TI_FE_filtered, TIII_FE_filtered, V_FE_filtered = filtered_data[46], filtered_data[48], filtered_data[50]
CR_FE_filtered, MN_FE_filtered, CO_FE_filtered, NI_FE_filtered = filtered_data[52], filtered_data[54], filtered_data[56], filtered_data[58]
RV_filtered  = filtered_data[9]

# %%
FE_H_err, C_FE_err, CI_FE_err = filtered_data[23], filtered_data[25], filtered_data[27]
N_FE_err, O_FE_err, MG_FE_err = filtered_data[29], filtered_data[31], filtered_data[33]
AL_FE_err, SI_FE_err, P_FE_err = filtered_data[35], filtered_data[37], filtered_data[39]
S_FE_err, K_FE_err, CA_FE_err = filtered_data[41], filtered_data[43], filtered_data[45]
TI_FE_err, TIII_FE_err, V_FE_err = filtered_data[47], filtered_data[49], filtered_data[51]
CR_FE_err, MN_FE_err, CO_FE_err, NI_FE_err = filtered_data[53], filtered_data[55], filtered_data[57], filtered_data[59]
RV_err  = filtered_data[10]

# %%
train_size = round(0.8 * len(filtered_data[0]))
test_size = round(0.1 * len(filtered_data[0]))
validation_size = round(0.1 * len(filtered_data[0]))

training_labels_raw = np.transpose(np.array([FE_H_filtered[:train_size], C_FE_filtered[:train_size], CI_FE_filtered[:train_size], 
                                        N_FE_filtered[:train_size], O_FE_filtered[:train_size], MG_FE_filtered[:train_size],
                                        AL_FE_filtered[:train_size], SI_FE_filtered[:train_size], P_FE_filtered[:train_size],
                                        S_FE_filtered[:train_size], K_FE_filtered[:train_size], CA_FE_filtered[:train_size],
                                        TI_FE_filtered[:train_size], TIII_FE_filtered[:train_size], V_FE_filtered[:train_size], 
                                        CR_FE_filtered[:train_size], MN_FE_filtered[:train_size], CO_FE_filtered[:train_size], NI_FE_filtered[:train_size]]))

error_training_labels_raw = np.transpose(np.array([FE_H_err[:train_size], C_FE_err[:train_size], CI_FE_err[:train_size], 
                                        N_FE_err[:train_size], O_FE_err[:train_size], MG_FE_err[:train_size],
                                        AL_FE_err[:train_size], SI_FE_err[:train_size], P_FE_err[:train_size],
                                        S_FE_err[:train_size], K_FE_err[:train_size], CA_FE_err[:train_size],
                                        TI_FE_err[:train_size], TIII_FE_err[:train_size], V_FE_err[:train_size], 
                                        CR_FE_err[:train_size], MN_FE_err[:train_size], CO_FE_err[:train_size], NI_FE_err[:train_size]]))


test_labels_raw = np.transpose(np.array([FE_H_filtered[train_size: train_size + test_size], C_FE_filtered[train_size: train_size + test_size], 
                                     CI_FE_filtered[train_size: train_size + test_size], N_FE_filtered[train_size: train_size + test_size],
                                     O_FE_filtered[train_size: train_size + test_size], MG_FE_filtered[train_size: train_size + test_size],
                                        AL_FE_filtered[train_size: train_size + test_size], SI_FE_filtered[train_size: train_size + test_size], 
                                     P_FE_filtered[train_size: train_size + test_size], S_FE_filtered[train_size: train_size + test_size], 
                                     K_FE_filtered[train_size: train_size + test_size], CA_FE_filtered[train_size: train_size + test_size],
                                        TI_FE_filtered[train_size: train_size + test_size], TIII_FE_filtered[train_size: train_size + test_size], 
                                     V_FE_filtered[train_size: train_size + test_size], CR_FE_filtered[train_size: train_size + test_size], 
                                     MN_FE_filtered[train_size: train_size + test_size], CO_FE_filtered[train_size: train_size + test_size], 
                                     NI_FE_filtered[train_size: train_size + test_size]]))
                                     
                                     
error_test_labels_raw = np.transpose(np.array([FE_H_err[train_size: train_size + test_size], C_FE_err[train_size: train_size + test_size], CI_FE_err[train_size: train_size + test_size], 
                                        N_FE_err[train_size: train_size + test_size], O_FE_err[train_size: train_size + test_size], MG_FE_err[train_size: train_size + test_size],
                                        AL_FE_err[train_size: train_size + test_size], SI_FE_err[train_size: train_size + test_size], P_FE_err[train_size: train_size + test_size],
                                        S_FE_err[train_size: train_size + test_size], K_FE_err[train_size: train_size + test_size], CA_FE_err[train_size: train_size + test_size],
                                        TI_FE_err[train_size: train_size + test_size], TIII_FE_err[train_size: train_size + test_size], V_FE_err[train_size: train_size + test_size], 
                                        CR_FE_err[train_size: train_size + test_size], MN_FE_err[train_size: train_size + test_size], CO_FE_err[train_size: train_size + test_size], NI_FE_err[train_size: train_size + test_size]]))


validation_labels_raw = np.transpose(np.array([FE_H_filtered[train_size + test_size: train_size + test_size + validation_size], C_FE_filtered[train_size + test_size: train_size + test_size + validation_size], 
                                     CI_FE_filtered[train_size + test_size: train_size + test_size + validation_size], N_FE_filtered[train_size + test_size: train_size + test_size + validation_size],
                                     O_FE_filtered[train_size + test_size: train_size + test_size + validation_size], MG_FE_filtered[train_size + test_size: train_size + test_size + validation_size],
                                        AL_FE_filtered[train_size + test_size: train_size + test_size + validation_size], SI_FE_filtered[train_size + test_size: train_size + test_size + validation_size], 
                                     P_FE_filtered[train_size + test_size: train_size + test_size + validation_size], S_FE_filtered[train_size + test_size: train_size + test_size + validation_size], 
                                     K_FE_filtered[train_size + test_size: train_size + test_size + validation_size], CA_FE_filtered[train_size + test_size: train_size + test_size + validation_size],
                                        TI_FE_filtered[train_size + test_size: train_size + test_size + validation_size], TIII_FE_filtered[train_size + test_size: train_size + test_size + validation_size], 
                                     V_FE_filtered[train_size + test_size: train_size + test_size + validation_size], CR_FE_filtered[train_size + test_size: train_size + test_size + validation_size], 
                                     MN_FE_filtered[train_size + test_size: train_size + test_size + validation_size], CO_FE_filtered[train_size + test_size: train_size + test_size + validation_size], 
                                     NI_FE_filtered[train_size + test_size: train_size + test_size + validation_size]]))
                                     
                                     
error_validation_labels_raw = np.transpose(np.array([FE_H_err[train_size + test_size: train_size + test_size + validation_size], C_FE_err[train_size + test_size: train_size + test_size + validation_size], CI_FE_err[train_size + test_size: train_size + test_size + validation_size], 
                                        N_FE_err[train_size + test_size: train_size + test_size + validation_size], O_FE_err[train_size + test_size: train_size + test_size + validation_size], MG_FE_err[train_size + test_size: train_size + test_size + validation_size],
                                        AL_FE_err[train_size + test_size: train_size + test_size + validation_size], SI_FE_err[train_size + test_size: train_size + test_size + validation_size], P_FE_err[train_size + test_size: train_size + test_size + validation_size],
                                        S_FE_err[train_size + test_size: train_size + test_size + validation_size], K_FE_err[train_size + test_size: train_size + test_size + validation_size], CA_FE_err[train_size + test_size: train_size + test_size + validation_size],
                                        TI_FE_err[train_size + test_size: train_size + test_size + validation_size], TIII_FE_err[train_size + test_size: train_size + test_size + validation_size], V_FE_err[train_size + test_size: train_size + test_size + validation_size], 
                                        CR_FE_err[train_size + test_size: train_size + test_size + validation_size], MN_FE_err[train_size + test_size: train_size + test_size + validation_size], CO_FE_err[train_size + test_size: train_size + test_size + validation_size], NI_FE_err[train_size + test_size: train_size + test_size + validation_size]]))

# %%
full_training_labels_raw = np.c_[training_labels_raw, error_training_labels_raw]
full_test_labels_raw = np.c_[test_labels_raw, error_test_labels_raw]
full_validation_labels_raw = np.c_[validation_labels_raw, error_validation_labels_raw]

# %%
full_training_labels_raw.shape, full_test_labels_raw.shape, full_validation_labels_raw.shape
# Out:
# ((115814, 38), (14477, 38), (14476, 38))

# %%
np.min(full_training_labels_raw.T, axis=1), np.max(full_training_labels_raw.T, axis=1)
# Out:
# (array([-1.951497  , -2.1234312 , -2.119044  , -0.18978369, -0.7124527 ,
#         -0.15558027, -0.47890055, -0.15707995, -0.97891414, -0.6047195 ,
#         -2.2741165 , -0.40278423, -1.2907453 , -0.6157368 , -1.1658391 ,
#         -1.391077  , -0.64225805, -3.6896837 , -0.2965148 ,  0.01358107,
#          0.01762647,  0.02378747,  0.01708818,  0.01984493,  0.02071843,
#          0.02232191,  0.01871411,  0.05818468,  0.01897749,  0.03516773,
#          0.02518716,  0.02486172,  0.02255343,  0.0375476 ,  0.02254345,
#          0.02762588,  0.01909786,  0.02221127]),
#  array([5.7460123e-01, 8.3517190e-01, 5.6674075e-01, 3.6616602e+00,
#         5.5585840e-01, 5.1025960e-01, 4.8934165e-01, 4.5210746e-01,
#         7.5247210e+00, 9.0582700e-01, 1.0242985e+00, 2.7282690e-01,
#         5.9501344e-01, 8.7636330e-01, 8.6697330e-01, 3.3210137e-01,
#         3.5304812e-01, 5.6587050e-01, 2.1270613e-01, 4.5790780e-01,
#         1.2761971e+00, 1.6784387e+00, 1.8850280e+01, 5.6260234e-01,
#         5.5715760e-01, 6.7058295e-01, 5.5592450e-01, 2.2155308e+01,
#         5.8074850e-01, 1.1802338e+04, 1.0069572e+00, 7.6264750e-01,
#         8.5684610e-01, 1.6342586e+00, 3.9144385e+00, 5.6938570e-01,
#         2.5924824e+03, 5.7262796e-01]))

# %%
err_threshold = 3 # remove errors that are larger than this...
err_mask_train = np.all(np.abs(full_training_labels_raw) < err_threshold, axis=1)
err_mask_test = np.all(np.abs(full_test_labels_raw) < err_threshold, axis=1)
err_mask_validation = np.all(np.abs(full_validation_labels_raw) < err_threshold, axis=1)

# %% [markdown]
# Remove unreasonably huge errors bars or unphysical abundance estimates:

# %%
full_training_labels = full_training_labels_raw[err_mask_train]
full_test_labels = full_test_labels_raw[err_mask_test]
full_validation_labels = full_validation_labels_raw[err_mask_validation]

# %%
full_training_labels.shape, full_test_labels.shape, full_validation_labels.shape
# Out:
# ((114885, 38), (14374, 38), (14326, 38))

# %%
np.min(full_training_labels.T, axis=1), np.max(full_training_labels.T, axis=1)
# Out:
# (array([-1.8320073 , -1.2602895 , -2.119044  , -0.18978369, -0.7124527 ,
#         -0.1388877 , -0.47890055, -0.13207644, -0.97891414, -0.5242982 ,
#         -0.7713039 , -0.40278423, -1.2907453 , -0.6157368 , -1.1658391 ,
#         -1.0536897 , -0.64225805, -1.1330373 , -0.2965148 ,  0.01358107,
#          0.01762647,  0.02378747,  0.01708818,  0.01984493,  0.02071843,
#          0.02232191,  0.01871411,  0.05818468,  0.01897749,  0.03516773,
#          0.02518716,  0.02486172,  0.02255343,  0.0375476 ,  0.02254345,
#          0.02762588,  0.01909786,  0.02221127]),
#  array([0.57460123, 0.81556314, 0.56674075, 1.5901425 , 0.5558584 ,
#         0.5102596 , 0.48934165, 0.45210746, 1.0318542 , 0.905827  ,
#         1.0242985 , 0.262527  , 0.59501344, 0.8763633 , 0.8669733 ,
#         0.27449507, 0.35304812, 0.5658705 , 0.21270613, 0.35667247,
#         0.48992783, 1.637775  , 1.0633858 , 0.46304193, 0.43964195,
#         0.55135024, 0.46292186, 2.998515  , 0.55373484, 2.87389   ,
#         1.0069572 , 0.7626475 , 0.8568461 , 1.6342586 , 1.6748365 ,
#         0.55016214, 2.8621614 , 0.57262796]))

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Manual scaler to standardize (equivalent to StandardScaler):

# %%
# standardized_pca_array = []
# standardization_means = np.zeros(len(np.array(x_df_transpose)))
# standardization_sigmas = np.zeros(len(np.array(x_df_transpose)))

# for i, param in enumerate(np.array(x_df_transpose)):
#     mean, sigma = np.mean(param), np.std(param)
#     norm = (param - mean)/sigma
#     standardized_pca_array.append(norm)
#     standardization_means[i] = mean
#     standardization_sigmas[i] = sigma

# %% [markdown]
# StandardScaler to standardize (same method for t-SNE/UMAP):

# %%
# split abundances and errors into separate datasets
training_labels_abundances = full_training_labels[:, :19]
training_labels_errors = full_training_labels[:, 19:]

test_labels_abundances = full_test_labels[:, :19]
test_labels_errors = full_test_labels[:, 19:]

validation_labels_abundances = full_validation_labels[:, :19]
validation_labels_errors = full_validation_labels[:, 19:]

standardized_abundance_training_arr = StandardScaler().fit_transform(training_labels_abundances)
standardized_error_training_arr = StandardScaler().fit_transform(training_labels_errors)
standardized_full_training_arr = StandardScaler().fit_transform(full_training_labels)

standardized_abundance_test_arr = StandardScaler().fit_transform(test_labels_abundances)
standardized_error_test_arr = StandardScaler().fit_transform(test_labels_errors)
standardized_full_test_arr = StandardScaler().fit_transform(full_test_labels)

standardized_abundance_validation_arr = StandardScaler().fit_transform(validation_labels_abundances)
standardized_error_validation_arr = StandardScaler().fit_transform(validation_labels_errors)
standardized_full_validation_arr = StandardScaler().fit_transform(full_validation_labels)

# %% [markdown]
# Begin VAE stuff:

# %% [markdown]
# # SAMPLING LAYER

# %%
class Sampling(layers.Layer):
    """Uses (mean, log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        mean, log_var = inputs
        batch = tf.shape(mean)[0]
        dim = tf.shape(mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return mean + tf.exp(0.5 * log_var) * epsilon

# %% [markdown]
# # ENCODER

# %%
latent_dim = 2

encoder_inputs = keras.Input(shape=(19,)) #to predict error, inputs is 38

x = tf.keras.layers.Dense(100, activation='gelu')(encoder_inputs)
x = tf.keras.layers.Dense(100, activation='gelu')(x)
x = tf.keras.layers.Dense(100, activation='gelu')(x)
x = tf.keras.layers.Dense(100, activation='gelu')(x)

mean = layers.Dense(latent_dim, name="mean")(x)
log_var = layers.Dense(latent_dim, name="log_var")(x)
z = Sampling()([mean, log_var])
encoder = keras.Model(encoder_inputs, [mean, log_var, z], name="encoder")
encoder.summary()
# Out:
# 2025-04-26 11:11:58.223456: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 19)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 100)       │      2,000 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 100)       │     10,100 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 100)       │     10,100 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 100)       │     10,100 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mean (Dense)        │ (None, 2)         │        202 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ log_var (Dense)     │ (None, 2)         │        202 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling (Sampling) │ (None, 2)         │          0 │ mean[0][0],       │
# │                     │                   │            │ log_var[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 32,704 (127.75 KB)
#  Trainable params: 32,704 (127.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Structure of old NN:
#     tf.keras.layers.Dense(100, activation='gelu'),
#     tf.keras.layers.Dense(100, activation='gelu'),
#     tf.keras.layers.Dense(100, activation='linear'),
#     tf.keras.layers.Dense(38)

# %% [markdown]
# # DECODER

# %%
latent_inputs = keras.Input(shape=(latent_dim,))

x = tf.keras.layers.Dense(100, activation="gelu")(latent_inputs)
x = tf.keras.layers.Dense(100, activation="gelu")(x)
x = tf.keras.layers.Dense(100, activation="gelu")(x)
x = tf.keras.layers.Dense(100, activation="gelu")(x)

decoder_outputs = layers.Dense(19, activation="linear")(x)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 100)            │           300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 19)             │         1,919 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,519 (127.03 KB)
#  Trainable params: 32,519 (127.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # DEFINE VAE

# %%
# alpha = 1e-15  # learning rate
# # optimizer uses Adam with learning rate 1e-7
# optimizer = tf.keras.optimizers.Adam(learning_rate = alpha)

# ### CUSTOM LR SCHEDULER
# lr_start   = 1e-7
# lr_max     = 1e-4
# lr_min     = 1e-12
# lr_ramp_ep  = 3
# lr_sus_ep  = 0
# lr_decay   = 0.7
   
# def lrfn(epoch, lr_start=lr_start, lr_max=lr_max, lr_min=lr_min, lr_ramp_ep=lr_ramp_ep, lr_sus_ep=lr_sus_ep, lr_decay=lr_decay):
#     if epoch < lr_ramp_ep:
#         lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
#     elif epoch < lr_ramp_ep + lr_sus_ep:
#         lr = lr_max
#     else:
#         lr = (lr_max - lr_min) * lr_decay **(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
#     return lr

# # Using this Custom Function, create a Callback
# lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

### COSINE ANNEALING

initial_lr = 1.e-4
decay_steps = int(1e5)  # total number of steps to decay over
alpha = 1.e-16          # minimum learning rate = alpha * initial_lr

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=initial_lr,
    decay_steps=decay_steps,
    alpha=alpha
)

# alpha=1e-7
# optimizer = tf.keras.optimizers.Adam(learning_rate = alpha)
 
def mse_loss(y_true, y_pred):
    r_loss = K.mean(K.square(y_true - y_pred), axis = [1,2,3])
    return 1000 * r_loss
 
def kl_loss(mean, log_var):
    kl_loss =  -0.5 * K.sum(1 + log_var - K.square(mean) - K.exp(log_var), axis = 1)
    return kl_loss
 
def vae_loss(y_true, y_pred, mean, var):
    r_loss = mse_loss(y_true, y_pred)
    kl_loss = kl_loss(mean, log_var)
    return  r_loss + kl_loss

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss") 
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]
    # train
    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.MSE(data, reconstruction) #for custom loss, average over 1 axis, change to custom loss here
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "total loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
    # evaluate
    def test_step(self, data):
        # encode
        z_mean, z_log_var, z = self.encoder(data)
        # reconstruct
        reconstruction = self.decoder(z)
        # compute losses
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                keras.losses.MSE(data, reconstruction) #for custom loss, average over 1 axis, change to custom loss here
            )
        )
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        total_loss = reconstruction_loss + kl_loss
        # update loss trackers
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        # return loss
        return {
            "total loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %% [markdown]
# # TRAIN

# %% [markdown]
# Train "naive" VAE:

# %%
# # training_labels, error_training_labels = full_training_labels[:, :19], full_training_labels[:, 19:]
# # test_labels, error_test_labels = full_test_labels[:, :19], full_test_labels[:, 19:]
# # validation_labels, error_validation_labels = full_validation_labels[:, :19], full_validation_labels[:, 19:]

# ### CHECKPOINTING:

# class EpochCheckpoint(tf.keras.callbacks.Callback):
#     def __init__(self, save_every=50, save_path='naive_vae_checkpoints/ckpt-epoch-{epoch:02d}.weights.h5'):
#         super().__init__()
#         self.save_every = save_every
#         self.save_path = save_path

#     def on_epoch_end(self, epoch, logs=None):
#         if (epoch + 1) % self.save_every == 0:
#             filepath = self.save_path.format(epoch=epoch + 1)
#             self.model.save_weights(filepath)
#             print(f"Checkpoint saved at epoch {epoch + 1}")

# # optimizer
# optimizer = keras.optimizers.Adam(learning_rate=lr_schedule)
# # VAE
# vae = VAE(encoder, decoder)
# vae.compile(optimizer=optimizer, metrics=['mse', 'accuracy'])
# # FIT
# # vae.fit(training_labels, epochs=5000, batch_size=256, callbacks=lr_callback)
# history = vae.fit(standardized_abundance_training_arr, 
#                   epochs=5000, batch_size=256, 
#                   validation_data=standardized_abundance_test_arr, 
#                   callbacks=[EpochCheckpoint(save_every=50)])
# Out:
# Epoch 1/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - kl_loss: 3.8201 - reconstruction_loss: 185.3714 - total loss: 189.1914 - val_total loss: 73.6596 - val_reconstruction_loss: 65.6912 - val_kl_loss: 7.9683
# Epoch 2/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 7.7049 - reconstruction_loss: 62.5690 - total loss: 70.2738 - val_total loss: 65.3667 - val_reconstruction_loss: 59.1144 - val_kl_loss: 6.2523
# Epoch 3/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 6.2582 - reconstruction_loss: 57.8745 - total loss: 64.1326 - val_total loss: 62.6481 - val_reconstruction_loss: 56.9711 - val_kl_loss: 5.6769
# Epoch 4/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.7436 - reconstruction_loss: 55.5281 - total loss: 61.2717 - val_total loss: 61.8807 - val_reconstruction_loss: 56.4453 - val_kl_loss: 5.4354
# Epoch 5/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.5657 - reconstruction_loss: 54.2248 - total loss: 59.7905 - val_total loss: 60.9881 - val_reconstruction_loss: 55.5993 - val_kl_loss: 5.3888
# Epoch 6/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.5074 - reconstruction_loss: 53.7518 - total loss: 59.2592 - val_total loss: 60.3559 - val_reconstruction_loss: 54.9650 - val_kl_loss: 5.3908
# Epoch 7/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.4836 - reconstruction_loss: 52.9352 - total loss: 58.4188 - val_total loss: 59.8825 - val_reconstruction_loss: 54.5061 - val_kl_loss: 5.3764
# Epoch 8/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.5049 - reconstruction_loss: 51.9108 - total loss: 57.4157 - val_total loss: 59.3414 - val_reconstruction_loss: 53.9464 - val_kl_loss: 5.3950
# Epoch 9/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.5014 - reconstruction_loss: 51.7289 - total loss: 57.2303 - val_total loss: 58.8691 - val_reconstruction_loss: 53.4463 - val_kl_loss: 5.4229
# Epoch 10/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.5276 - reconstruction_loss: 51.0296 - total loss: 56.5572 - val_total loss: 58.4851 - val_reconstruction_loss: 53.0326 - val_kl_loss: 5.4526
# Epoch 11/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.5585 - reconstruction_loss: 50.2084 - total loss: 55.7669 - val_total loss: 58.3956 - val_reconstruction_loss: 52.9274 - val_kl_loss: 5.4681
# Epoch 12/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.5804 - reconstruction_loss: 49.0627 - total loss: 54.6431 - val_total loss: 57.7608 - val_reconstruction_loss: 52.2460 - val_kl_loss: 5.5148
# Epoch 13/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.5868 - reconstruction_loss: 49.3001 - total loss: 54.8869 - val_total loss: 57.3461 - val_reconstruction_loss: 51.8670 - val_kl_loss: 5.4790
# Epoch 14/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.5902 - reconstruction_loss: 48.1298 - total loss: 53.7200 - val_total loss: 57.5210 - val_reconstruction_loss: 51.9898 - val_kl_loss: 5.5312
# Epoch 15/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.6267 - reconstruction_loss: 48.3444 - total loss: 53.9710 - val_total loss: 56.8269 - val_reconstruction_loss: 51.3109 - val_kl_loss: 5.5160
# Epoch 16/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.6208 - reconstruction_loss: 47.7280 - total loss: 53.3488 - val_total loss: 56.8295 - val_reconstruction_loss: 51.3030 - val_kl_loss: 5.5265
# Epoch 17/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.6395 - reconstruction_loss: 47.6155 - total loss: 53.2549 - val_total loss: 56.3832 - val_reconstruction_loss: 50.8718 - val_kl_loss: 5.5114
# Epoch 18/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.6115 - reconstruction_loss: 47.2012 - total loss: 52.8126 - val_total loss: 56.1522 - val_reconstruction_loss: 50.6149 - val_kl_loss: 5.5373
# Epoch 19/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.6420 - reconstruction_loss: 46.8507 - total loss: 52.4926 - val_total loss: 55.8899 - val_reconstruction_loss: 50.3667 - val_kl_loss: 5.5232
# Epoch 20/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.6294 - reconstruction_loss: 46.6843 - total loss: 52.3137 - val_total loss: 55.3773 - val_reconstruction_loss: 49.8463 - val_kl_loss: 5.5309
# Epoch 21/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.6531 - reconstruction_loss: 46.4137 - total loss: 52.0668 - val_total loss: 55.4145 - val_reconstruction_loss: 49.8400 - val_kl_loss: 5.5745
# Epoch 22/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.6730 - reconstruction_loss: 46.0364 - total loss: 51.7094 - val_total loss: 55.1695 - val_reconstruction_loss: 49.6004 - val_kl_loss: 5.5691
# Epoch 23/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.6795 - reconstruction_loss: 45.8946 - total loss: 51.5742 - val_total loss: 54.8981 - val_reconstruction_loss: 49.2998 - val_kl_loss: 5.5983
# Epoch 24/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.6953 - reconstruction_loss: 45.1602 - total loss: 50.8555 - val_total loss: 54.7106 - val_reconstruction_loss: 49.1091 - val_kl_loss: 5.6015
# Epoch 25/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7060 - reconstruction_loss: 45.1903 - total loss: 50.8963 - val_total loss: 54.7775 - val_reconstruction_loss: 49.1494 - val_kl_loss: 5.6280
# Epoch 26/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7107 - reconstruction_loss: 45.1496 - total loss: 50.8602 - val_total loss: 54.3268 - val_reconstruction_loss: 48.6715 - val_kl_loss: 5.6553
# Epoch 27/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7256 - reconstruction_loss: 44.7381 - total loss: 50.4637 - val_total loss: 54.4457 - val_reconstruction_loss: 48.8034 - val_kl_loss: 5.6423
# Epoch 28/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7115 - reconstruction_loss: 44.6789 - total loss: 50.3904 - val_total loss: 54.1252 - val_reconstruction_loss: 48.4677 - val_kl_loss: 5.6575
# Epoch 29/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7397 - reconstruction_loss: 44.4683 - total loss: 50.2080 - val_total loss: 53.7193 - val_reconstruction_loss: 48.0639 - val_kl_loss: 5.6553
# Epoch 30/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7510 - reconstruction_loss: 44.7049 - total loss: 50.4559 - val_total loss: 53.9794 - val_reconstruction_loss: 48.3077 - val_kl_loss: 5.6718
# Epoch 31/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7512 - reconstruction_loss: 44.2282 - total loss: 49.9794 - val_total loss: 53.5334 - val_reconstruction_loss: 47.8446 - val_kl_loss: 5.6888
# Epoch 32/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7707 - reconstruction_loss: 44.0227 - total loss: 49.7934 - val_total loss: 53.5028 - val_reconstruction_loss: 47.8361 - val_kl_loss: 5.6667
# Epoch 33/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7826 - reconstruction_loss: 44.3721 - total loss: 50.1548 - val_total loss: 53.3121 - val_reconstruction_loss: 47.6182 - val_kl_loss: 5.6939
# Epoch 34/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7900 - reconstruction_loss: 43.7414 - total loss: 49.5315 - val_total loss: 53.2740 - val_reconstruction_loss: 47.5730 - val_kl_loss: 5.7010
# Epoch 35/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7917 - reconstruction_loss: 43.4632 - total loss: 49.2549 - val_total loss: 53.2505 - val_reconstruction_loss: 47.5549 - val_kl_loss: 5.6956
# Epoch 36/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.7999 - reconstruction_loss: 43.0911 - total loss: 48.8910 - val_total loss: 52.9878 - val_reconstruction_loss: 47.2749 - val_kl_loss: 5.7129
# Epoch 37/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8255 - reconstruction_loss: 43.0718 - total loss: 48.8973 - val_total loss: 52.6704 - val_reconstruction_loss: 46.9436 - val_kl_loss: 5.7268
# Epoch 38/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8184 - reconstruction_loss: 43.2593 - total loss: 49.0777 - val_total loss: 52.7543 - val_reconstruction_loss: 47.0493 - val_kl_loss: 5.7051
# Epoch 39/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8233 - reconstruction_loss: 42.3643 - total loss: 48.1876 - val_total loss: 52.7289 - val_reconstruction_loss: 46.9898 - val_kl_loss: 5.7390
# Epoch 40/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8397 - reconstruction_loss: 42.6572 - total loss: 48.4968 - val_total loss: 52.3606 - val_reconstruction_loss: 46.6545 - val_kl_loss: 5.7061
# Epoch 41/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8262 - reconstruction_loss: 42.7614 - total loss: 48.5876 - val_total loss: 52.3190 - val_reconstruction_loss: 46.5604 - val_kl_loss: 5.7586
# Epoch 42/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8596 - reconstruction_loss: 42.6639 - total loss: 48.5235 - val_total loss: 51.7599 - val_reconstruction_loss: 45.9995 - val_kl_loss: 5.7604
# Epoch 43/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8588 - reconstruction_loss: 42.5149 - total loss: 48.3737 - val_total loss: 51.8742 - val_reconstruction_loss: 46.1249 - val_kl_loss: 5.7493
# Epoch 44/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8604 - reconstruction_loss: 42.5753 - total loss: 48.4357 - val_total loss: 51.7062 - val_reconstruction_loss: 45.9464 - val_kl_loss: 5.7598
# Epoch 45/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8632 - reconstruction_loss: 42.0055 - total loss: 47.8687 - val_total loss: 51.6578 - val_reconstruction_loss: 45.8930 - val_kl_loss: 5.7648
# Epoch 46/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8887 - reconstruction_loss: 42.1816 - total loss: 48.0703 - val_total loss: 51.5176 - val_reconstruction_loss: 45.7429 - val_kl_loss: 5.7747
# Epoch 47/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8842 - reconstruction_loss: 41.7169 - total loss: 47.6010 - val_total loss: 51.3865 - val_reconstruction_loss: 45.5998 - val_kl_loss: 5.7867
# Epoch 48/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.8853 - reconstruction_loss: 42.1404 - total loss: 48.0258 - val_total loss: 51.5430 - val_reconstruction_loss: 45.7719 - val_kl_loss: 5.7711
# Epoch 49/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9013 - reconstruction_loss: 41.5056 - total loss: 47.4069 - val_total loss: 51.5512 - val_reconstruction_loss: 45.7632 - val_kl_loss: 5.7881
# Epoch 50/5000
# 441/449 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_loss: 5.8959 - reconstruction_loss: 41.2177 - total loss: 47.1136Checkpoint saved at epoch 50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.8962 - reconstruction_loss: 41.2232 - total loss: 47.1194 - val_total loss: 51.3389 - val_reconstruction_loss: 45.5236 - val_kl_loss: 5.8153
# Epoch 51/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9215 - reconstruction_loss: 41.3138 - total loss: 47.2352 - val_total loss: 51.3674 - val_reconstruction_loss: 45.5403 - val_kl_loss: 5.8271
# Epoch 52/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9262 - reconstruction_loss: 41.1042 - total loss: 47.0304 - val_total loss: 51.0037 - val_reconstruction_loss: 45.1902 - val_kl_loss: 5.8134
# Epoch 53/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9388 - reconstruction_loss: 41.3080 - total loss: 47.2468 - val_total loss: 51.0793 - val_reconstruction_loss: 45.2803 - val_kl_loss: 5.7990
# Epoch 54/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9290 - reconstruction_loss: 41.2509 - total loss: 47.1799 - val_total loss: 50.8838 - val_reconstruction_loss: 45.0649 - val_kl_loss: 5.8188
# Epoch 55/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9497 - reconstruction_loss: 40.9320 - total loss: 46.8817 - val_total loss: 50.5170 - val_reconstruction_loss: 44.6781 - val_kl_loss: 5.8389
# Epoch 56/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 5.9600 - reconstruction_loss: 40.9518 - total loss: 46.9118 - val_total loss: 50.7104 - val_reconstruction_loss: 44.8385 - val_kl_loss: 5.8720
# Epoch 57/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9535 - reconstruction_loss: 40.7397 - total loss: 46.6931 - val_total loss: 50.2226 - val_reconstruction_loss: 44.4264 - val_kl_loss: 5.7962
# Epoch 58/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9512 - reconstruction_loss: 40.5408 - total loss: 46.4919 - val_total loss: 50.4499 - val_reconstruction_loss: 44.6524 - val_kl_loss: 5.7975
# Epoch 59/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9564 - reconstruction_loss: 40.7623 - total loss: 46.7188 - val_total loss: 50.0711 - val_reconstruction_loss: 44.2586 - val_kl_loss: 5.8125
# Epoch 60/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9511 - reconstruction_loss: 40.2273 - total loss: 46.1784 - val_total loss: 50.3086 - val_reconstruction_loss: 44.4712 - val_kl_loss: 5.8375
# Epoch 61/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9721 - reconstruction_loss: 40.0600 - total loss: 46.0320 - val_total loss: 50.1373 - val_reconstruction_loss: 44.2677 - val_kl_loss: 5.8696
# Epoch 62/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9753 - reconstruction_loss: 40.3911 - total loss: 46.3663 - val_total loss: 49.9166 - val_reconstruction_loss: 44.0462 - val_kl_loss: 5.8704
# Epoch 63/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9827 - reconstruction_loss: 40.3750 - total loss: 46.3577 - val_total loss: 49.8423 - val_reconstruction_loss: 43.9675 - val_kl_loss: 5.8748
# Epoch 64/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9927 - reconstruction_loss: 40.0778 - total loss: 46.0705 - val_total loss: 49.9328 - val_reconstruction_loss: 44.0643 - val_kl_loss: 5.8685
# Epoch 65/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9833 - reconstruction_loss: 39.7837 - total loss: 45.7670 - val_total loss: 49.9069 - val_reconstruction_loss: 44.0459 - val_kl_loss: 5.8610
# Epoch 66/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9948 - reconstruction_loss: 39.9951 - total loss: 45.9899 - val_total loss: 50.1390 - val_reconstruction_loss: 44.2440 - val_kl_loss: 5.8950
# Epoch 67/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0212 - reconstruction_loss: 39.8161 - total loss: 45.8373 - val_total loss: 49.7182 - val_reconstruction_loss: 43.8622 - val_kl_loss: 5.8560
# Epoch 68/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9964 - reconstruction_loss: 39.8530 - total loss: 45.8494 - val_total loss: 50.2595 - val_reconstruction_loss: 44.3762 - val_kl_loss: 5.8833
# Epoch 69/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.9967 - reconstruction_loss: 39.7219 - total loss: 45.7186 - val_total loss: 49.9611 - val_reconstruction_loss: 44.0515 - val_kl_loss: 5.9096
# Epoch 70/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0214 - reconstruction_loss: 39.7203 - total loss: 45.7417 - val_total loss: 49.7285 - val_reconstruction_loss: 43.8302 - val_kl_loss: 5.8983
# Epoch 71/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0150 - reconstruction_loss: 39.6186 - total loss: 45.6336 - val_total loss: 49.4661 - val_reconstruction_loss: 43.5187 - val_kl_loss: 5.9474
# Epoch 72/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0248 - reconstruction_loss: 39.4947 - total loss: 45.5195 - val_total loss: 49.7375 - val_reconstruction_loss: 43.8365 - val_kl_loss: 5.9010
# Epoch 73/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0182 - reconstruction_loss: 39.2796 - total loss: 45.2978 - val_total loss: 49.9827 - val_reconstruction_loss: 44.0729 - val_kl_loss: 5.9098
# Epoch 74/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0208 - reconstruction_loss: 39.2084 - total loss: 45.2292 - val_total loss: 49.9290 - val_reconstruction_loss: 44.0352 - val_kl_loss: 5.8938
# Epoch 75/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0390 - reconstruction_loss: 39.1112 - total loss: 45.1501 - val_total loss: 49.8102 - val_reconstruction_loss: 43.8787 - val_kl_loss: 5.9314
# Epoch 76/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0281 - reconstruction_loss: 39.4108 - total loss: 45.4389 - val_total loss: 49.5239 - val_reconstruction_loss: 43.6300 - val_kl_loss: 5.8939
# Epoch 77/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0319 - reconstruction_loss: 39.3543 - total loss: 45.3863 - val_total loss: 49.5395 - val_reconstruction_loss: 43.6161 - val_kl_loss: 5.9235
# Epoch 78/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0374 - reconstruction_loss: 39.1367 - total loss: 45.1742 - val_total loss: 49.2318 - val_reconstruction_loss: 43.3198 - val_kl_loss: 5.9120
# Epoch 79/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0375 - reconstruction_loss: 39.3361 - total loss: 45.3736 - val_total loss: 49.4953 - val_reconstruction_loss: 43.5787 - val_kl_loss: 5.9166
# Epoch 80/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0239 - reconstruction_loss: 38.8921 - total loss: 44.9160 - val_total loss: 49.3095 - val_reconstruction_loss: 43.4011 - val_kl_loss: 5.9084
# Epoch 81/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0334 - reconstruction_loss: 39.4500 - total loss: 45.4834 - val_total loss: 49.6105 - val_reconstruction_loss: 43.6870 - val_kl_loss: 5.9236
# Epoch 82/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0489 - reconstruction_loss: 39.0206 - total loss: 45.0694 - val_total loss: 49.3761 - val_reconstruction_loss: 43.4476 - val_kl_loss: 5.9285
# Epoch 83/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0508 - reconstruction_loss: 38.8819 - total loss: 44.9327 - val_total loss: 49.2479 - val_reconstruction_loss: 43.3135 - val_kl_loss: 5.9344
# Epoch 84/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0479 - reconstruction_loss: 39.1714 - total loss: 45.2193 - val_total loss: 49.0888 - val_reconstruction_loss: 43.1324 - val_kl_loss: 5.9564
# Epoch 85/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0565 - reconstruction_loss: 39.2110 - total loss: 45.2674 - val_total loss: 49.2949 - val_reconstruction_loss: 43.3648 - val_kl_loss: 5.9301
# Epoch 86/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0528 - reconstruction_loss: 38.9440 - total loss: 44.9969 - val_total loss: 49.5730 - val_reconstruction_loss: 43.6439 - val_kl_loss: 5.9291
# Epoch 87/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0536 - reconstruction_loss: 38.7520 - total loss: 44.8056 - val_total loss: 49.1443 - val_reconstruction_loss: 43.1860 - val_kl_loss: 5.9583
# Epoch 88/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0673 - reconstruction_loss: 38.6928 - total loss: 44.7601 - val_total loss: 48.9818 - val_reconstruction_loss: 43.0310 - val_kl_loss: 5.9508
# Epoch 89/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0608 - reconstruction_loss: 38.7346 - total loss: 44.7954 - val_total loss: 49.3729 - val_reconstruction_loss: 43.4324 - val_kl_loss: 5.9404
# Epoch 90/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0655 - reconstruction_loss: 38.9264 - total loss: 44.9920 - val_total loss: 49.3492 - val_reconstruction_loss: 43.4180 - val_kl_loss: 5.9312
# Epoch 91/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0604 - reconstruction_loss: 38.6394 - total loss: 44.6999 - val_total loss: 48.9846 - val_reconstruction_loss: 43.0387 - val_kl_loss: 5.9459
# Epoch 92/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0698 - reconstruction_loss: 38.1503 - total loss: 44.2201 - val_total loss: 49.1044 - val_reconstruction_loss: 43.1796 - val_kl_loss: 5.9248
# Epoch 93/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0667 - reconstruction_loss: 38.4689 - total loss: 44.5357 - val_total loss: 49.2345 - val_reconstruction_loss: 43.2697 - val_kl_loss: 5.9647
# Epoch 94/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0807 - reconstruction_loss: 38.3803 - total loss: 44.4611 - val_total loss: 49.1593 - val_reconstruction_loss: 43.1897 - val_kl_loss: 5.9696
# Epoch 95/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0758 - reconstruction_loss: 38.3431 - total loss: 44.4189 - val_total loss: 48.9695 - val_reconstruction_loss: 43.0026 - val_kl_loss: 5.9668
# Epoch 96/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0929 - reconstruction_loss: 38.5031 - total loss: 44.5961 - val_total loss: 49.0174 - val_reconstruction_loss: 43.0521 - val_kl_loss: 5.9654
# Epoch 97/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0794 - reconstruction_loss: 38.3782 - total loss: 44.4576 - val_total loss: 48.9180 - val_reconstruction_loss: 42.9272 - val_kl_loss: 5.9909
# Epoch 98/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0876 - reconstruction_loss: 38.5001 - total loss: 44.5877 - val_total loss: 49.0548 - val_reconstruction_loss: 43.0785 - val_kl_loss: 5.9763
# Epoch 99/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0942 - reconstruction_loss: 37.9893 - total loss: 44.0835 - val_total loss: 48.9100 - val_reconstruction_loss: 42.9195 - val_kl_loss: 5.9906
# Epoch 100/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_loss: 6.0998 - reconstruction_loss: 38.4914 - total loss: 44.5913Checkpoint saved at epoch 100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0998 - reconstruction_loss: 38.4910 - total loss: 44.5908 - val_total loss: 48.9029 - val_reconstruction_loss: 42.9074 - val_kl_loss: 5.9955
# Epoch 101/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0992 - reconstruction_loss: 38.0842 - total loss: 44.1834 - val_total loss: 48.9221 - val_reconstruction_loss: 42.9638 - val_kl_loss: 5.9583
# Epoch 102/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0777 - reconstruction_loss: 37.7787 - total loss: 43.8564 - val_total loss: 48.7469 - val_reconstruction_loss: 42.7934 - val_kl_loss: 5.9535
# Epoch 103/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0948 - reconstruction_loss: 38.3494 - total loss: 44.4442 - val_total loss: 48.8866 - val_reconstruction_loss: 42.9037 - val_kl_loss: 5.9829
# Epoch 104/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0893 - reconstruction_loss: 38.1092 - total loss: 44.1985 - val_total loss: 48.8727 - val_reconstruction_loss: 42.8755 - val_kl_loss: 5.9972
# Epoch 105/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0950 - reconstruction_loss: 38.1605 - total loss: 44.2554 - val_total loss: 48.7449 - val_reconstruction_loss: 42.7766 - val_kl_loss: 5.9683
# Epoch 106/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1045 - reconstruction_loss: 38.0550 - total loss: 44.1595 - val_total loss: 48.5800 - val_reconstruction_loss: 42.5840 - val_kl_loss: 5.9960
# Epoch 107/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0967 - reconstruction_loss: 37.7931 - total loss: 43.8898 - val_total loss: 48.7004 - val_reconstruction_loss: 42.6944 - val_kl_loss: 6.0060
# Epoch 108/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.0991 - reconstruction_loss: 37.7673 - total loss: 43.8665 - val_total loss: 48.5562 - val_reconstruction_loss: 42.5629 - val_kl_loss: 5.9933
# Epoch 109/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1076 - reconstruction_loss: 37.9798 - total loss: 44.0874 - val_total loss: 48.8885 - val_reconstruction_loss: 42.8870 - val_kl_loss: 6.0015
# Epoch 110/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1117 - reconstruction_loss: 37.9792 - total loss: 44.0909 - val_total loss: 48.7898 - val_reconstruction_loss: 42.7951 - val_kl_loss: 5.9946
# Epoch 111/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1053 - reconstruction_loss: 37.9398 - total loss: 44.0452 - val_total loss: 48.7988 - val_reconstruction_loss: 42.8132 - val_kl_loss: 5.9856
# Epoch 112/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1065 - reconstruction_loss: 38.1380 - total loss: 44.2445 - val_total loss: 48.6630 - val_reconstruction_loss: 42.7134 - val_kl_loss: 5.9496
# Epoch 113/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1024 - reconstruction_loss: 37.9832 - total loss: 44.0856 - val_total loss: 48.5791 - val_reconstruction_loss: 42.5985 - val_kl_loss: 5.9806
# Epoch 114/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1155 - reconstruction_loss: 37.8239 - total loss: 43.9395 - val_total loss: 48.6428 - val_reconstruction_loss: 42.6498 - val_kl_loss: 5.9931
# Epoch 115/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1056 - reconstruction_loss: 37.9043 - total loss: 44.0100 - val_total loss: 48.5501 - val_reconstruction_loss: 42.5560 - val_kl_loss: 5.9941
# Epoch 116/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1239 - reconstruction_loss: 37.9021 - total loss: 44.0260 - val_total loss: 48.6559 - val_reconstruction_loss: 42.6672 - val_kl_loss: 5.9886
# Epoch 117/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1037 - reconstruction_loss: 37.6224 - total loss: 43.7260 - val_total loss: 48.7859 - val_reconstruction_loss: 42.7981 - val_kl_loss: 5.9878
# Epoch 118/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1054 - reconstruction_loss: 37.8258 - total loss: 43.9312 - val_total loss: 48.4536 - val_reconstruction_loss: 42.4660 - val_kl_loss: 5.9876
# Epoch 119/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1123 - reconstruction_loss: 37.9741 - total loss: 44.0864 - val_total loss: 48.7085 - val_reconstruction_loss: 42.7248 - val_kl_loss: 5.9837
# Epoch 120/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1161 - reconstruction_loss: 37.7675 - total loss: 43.8835 - val_total loss: 48.3642 - val_reconstruction_loss: 42.3875 - val_kl_loss: 5.9768
# Epoch 121/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1253 - reconstruction_loss: 37.8932 - total loss: 44.0185 - val_total loss: 48.3575 - val_reconstruction_loss: 42.3349 - val_kl_loss: 6.0227
# Epoch 122/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1255 - reconstruction_loss: 37.7174 - total loss: 43.8429 - val_total loss: 48.4250 - val_reconstruction_loss: 42.4244 - val_kl_loss: 6.0006
# Epoch 123/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1251 - reconstruction_loss: 37.4628 - total loss: 43.5879 - val_total loss: 48.6113 - val_reconstruction_loss: 42.6336 - val_kl_loss: 5.9777
# Epoch 124/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1068 - reconstruction_loss: 37.7565 - total loss: 43.8633 - val_total loss: 48.4770 - val_reconstruction_loss: 42.4871 - val_kl_loss: 5.9899
# Epoch 125/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1191 - reconstruction_loss: 37.6474 - total loss: 43.7665 - val_total loss: 48.2201 - val_reconstruction_loss: 42.2185 - val_kl_loss: 6.0016
# Epoch 126/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1127 - reconstruction_loss: 37.3492 - total loss: 43.4619 - val_total loss: 48.4938 - val_reconstruction_loss: 42.4985 - val_kl_loss: 5.9953
# Epoch 127/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1249 - reconstruction_loss: 37.3239 - total loss: 43.4488 - val_total loss: 48.4172 - val_reconstruction_loss: 42.4229 - val_kl_loss: 5.9943
# Epoch 128/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1230 - reconstruction_loss: 37.6156 - total loss: 43.7387 - val_total loss: 48.4529 - val_reconstruction_loss: 42.4438 - val_kl_loss: 6.0091
# Epoch 129/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1349 - reconstruction_loss: 37.5501 - total loss: 43.6851 - val_total loss: 48.4202 - val_reconstruction_loss: 42.4097 - val_kl_loss: 6.0104
# Epoch 130/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1264 - reconstruction_loss: 37.6673 - total loss: 43.7938 - val_total loss: 48.1501 - val_reconstruction_loss: 42.1472 - val_kl_loss: 6.0029
# Epoch 131/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1288 - reconstruction_loss: 37.6692 - total loss: 43.7980 - val_total loss: 48.2399 - val_reconstruction_loss: 42.2388 - val_kl_loss: 6.0011
# Epoch 132/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1244 - reconstruction_loss: 37.7280 - total loss: 43.8524 - val_total loss: 48.2990 - val_reconstruction_loss: 42.2931 - val_kl_loss: 6.0060
# Epoch 133/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1221 - reconstruction_loss: 37.5035 - total loss: 43.6256 - val_total loss: 48.3371 - val_reconstruction_loss: 42.3388 - val_kl_loss: 5.9983
# Epoch 134/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1274 - reconstruction_loss: 37.0654 - total loss: 43.1928 - val_total loss: 48.4209 - val_reconstruction_loss: 42.4128 - val_kl_loss: 6.0081
# Epoch 135/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1189 - reconstruction_loss: 37.1893 - total loss: 43.3082 - val_total loss: 48.2992 - val_reconstruction_loss: 42.2768 - val_kl_loss: 6.0224
# Epoch 136/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1188 - reconstruction_loss: 37.3683 - total loss: 43.4870 - val_total loss: 48.3383 - val_reconstruction_loss: 42.3273 - val_kl_loss: 6.0111
# Epoch 137/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1297 - reconstruction_loss: 37.0297 - total loss: 43.1594 - val_total loss: 48.1668 - val_reconstruction_loss: 42.1645 - val_kl_loss: 6.0023
# Epoch 138/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1329 - reconstruction_loss: 37.4348 - total loss: 43.5677 - val_total loss: 48.2236 - val_reconstruction_loss: 42.2065 - val_kl_loss: 6.0170
# Epoch 139/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1289 - reconstruction_loss: 37.4282 - total loss: 43.5571 - val_total loss: 48.3035 - val_reconstruction_loss: 42.2822 - val_kl_loss: 6.0212
# Epoch 140/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1499 - reconstruction_loss: 37.2161 - total loss: 43.3661 - val_total loss: 48.3846 - val_reconstruction_loss: 42.3838 - val_kl_loss: 6.0008
# Epoch 141/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1266 - reconstruction_loss: 37.2657 - total loss: 43.3923 - val_total loss: 48.0018 - val_reconstruction_loss: 41.9891 - val_kl_loss: 6.0127
# Epoch 142/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1379 - reconstruction_loss: 37.2142 - total loss: 43.3521 - val_total loss: 48.2322 - val_reconstruction_loss: 42.1993 - val_kl_loss: 6.0328
# Epoch 143/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1488 - reconstruction_loss: 37.2533 - total loss: 43.4021 - val_total loss: 48.1279 - val_reconstruction_loss: 42.1033 - val_kl_loss: 6.0245
# Epoch 144/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1297 - reconstruction_loss: 37.2145 - total loss: 43.3443 - val_total loss: 48.2089 - val_reconstruction_loss: 42.1713 - val_kl_loss: 6.0375
# Epoch 145/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1545 - reconstruction_loss: 37.3721 - total loss: 43.5266 - val_total loss: 48.2412 - val_reconstruction_loss: 42.2319 - val_kl_loss: 6.0094
# Epoch 146/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1359 - reconstruction_loss: 37.1789 - total loss: 43.3147 - val_total loss: 48.1484 - val_reconstruction_loss: 42.1272 - val_kl_loss: 6.0212
# Epoch 147/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1467 - reconstruction_loss: 37.4270 - total loss: 43.5738 - val_total loss: 48.2579 - val_reconstruction_loss: 42.2361 - val_kl_loss: 6.0218
# Epoch 148/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1368 - reconstruction_loss: 37.4354 - total loss: 43.5722 - val_total loss: 48.1660 - val_reconstruction_loss: 42.1421 - val_kl_loss: 6.0238
# Epoch 149/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1415 - reconstruction_loss: 37.0936 - total loss: 43.2351 - val_total loss: 48.2816 - val_reconstruction_loss: 42.2749 - val_kl_loss: 6.0067
# Epoch 150/5000
# 444/449 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_loss: 6.1369 - reconstruction_loss: 37.2848 - total loss: 43.4217Checkpoint saved at epoch 150
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 6.1369 - reconstruction_loss: 37.2835 - total loss: 43.4204 - val_total loss: 48.0133 - val_reconstruction_loss: 41.9989 - val_kl_loss: 6.0144
# Epoch 151/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1429 - reconstruction_loss: 37.3737 - total loss: 43.5167 - val_total loss: 48.0780 - val_reconstruction_loss: 42.0560 - val_kl_loss: 6.0220
# Epoch 152/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1512 - reconstruction_loss: 37.1517 - total loss: 43.3029 - val_total loss: 47.9889 - val_reconstruction_loss: 41.9551 - val_kl_loss: 6.0338
# Epoch 153/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1527 - reconstruction_loss: 36.8974 - total loss: 43.0501 - val_total loss: 48.0399 - val_reconstruction_loss: 42.0041 - val_kl_loss: 6.0358
# Epoch 154/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1397 - reconstruction_loss: 37.2401 - total loss: 43.3798 - val_total loss: 48.1523 - val_reconstruction_loss: 42.1352 - val_kl_loss: 6.0171
# Epoch 155/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1372 - reconstruction_loss: 37.0395 - total loss: 43.1767 - val_total loss: 48.0265 - val_reconstruction_loss: 41.9824 - val_kl_loss: 6.0440
# Epoch 156/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1520 - reconstruction_loss: 37.0201 - total loss: 43.1721 - val_total loss: 47.9901 - val_reconstruction_loss: 41.9634 - val_kl_loss: 6.0267
# Epoch 157/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1426 - reconstruction_loss: 36.7348 - total loss: 42.8774 - val_total loss: 47.9453 - val_reconstruction_loss: 41.9175 - val_kl_loss: 6.0277
# Epoch 158/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1437 - reconstruction_loss: 36.9185 - total loss: 43.0622 - val_total loss: 48.1143 - val_reconstruction_loss: 42.0894 - val_kl_loss: 6.0249
# Epoch 159/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1500 - reconstruction_loss: 37.3983 - total loss: 43.5483 - val_total loss: 48.0586 - val_reconstruction_loss: 42.0425 - val_kl_loss: 6.0161
# Epoch 160/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1482 - reconstruction_loss: 37.2561 - total loss: 43.4043 - val_total loss: 48.1266 - val_reconstruction_loss: 42.0916 - val_kl_loss: 6.0349
# Epoch 161/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1497 - reconstruction_loss: 36.9459 - total loss: 43.0956 - val_total loss: 48.0604 - val_reconstruction_loss: 42.0170 - val_kl_loss: 6.0434
# Epoch 162/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1504 - reconstruction_loss: 36.9114 - total loss: 43.0618 - val_total loss: 48.1852 - val_reconstruction_loss: 42.1601 - val_kl_loss: 6.0252
# Epoch 163/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1546 - reconstruction_loss: 37.4047 - total loss: 43.5593 - val_total loss: 48.0555 - val_reconstruction_loss: 42.0239 - val_kl_loss: 6.0316
# Epoch 164/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1472 - reconstruction_loss: 37.1257 - total loss: 43.2730 - val_total loss: 48.0659 - val_reconstruction_loss: 42.0413 - val_kl_loss: 6.0245
# Epoch 165/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1604 - reconstruction_loss: 37.2616 - total loss: 43.4220 - val_total loss: 47.9964 - val_reconstruction_loss: 41.9618 - val_kl_loss: 6.0346
# Epoch 166/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1550 - reconstruction_loss: 37.2510 - total loss: 43.4061 - val_total loss: 48.0086 - val_reconstruction_loss: 41.9785 - val_kl_loss: 6.0301
# Epoch 167/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1485 - reconstruction_loss: 37.0862 - total loss: 43.2347 - val_total loss: 48.0454 - val_reconstruction_loss: 42.0248 - val_kl_loss: 6.0207
# Epoch 168/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1397 - reconstruction_loss: 37.1240 - total loss: 43.2636 - val_total loss: 48.0587 - val_reconstruction_loss: 42.0218 - val_kl_loss: 6.0368
# Epoch 169/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1504 - reconstruction_loss: 36.8343 - total loss: 42.9847 - val_total loss: 48.0249 - val_reconstruction_loss: 42.0004 - val_kl_loss: 6.0244
# Epoch 170/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1520 - reconstruction_loss: 37.0534 - total loss: 43.2054 - val_total loss: 47.9241 - val_reconstruction_loss: 41.8831 - val_kl_loss: 6.0411
# Epoch 171/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1560 - reconstruction_loss: 37.1993 - total loss: 43.3553 - val_total loss: 47.9828 - val_reconstruction_loss: 41.9420 - val_kl_loss: 6.0408
# Epoch 172/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1491 - reconstruction_loss: 36.9827 - total loss: 43.1317 - val_total loss: 47.9785 - val_reconstruction_loss: 41.9420 - val_kl_loss: 6.0365
# Epoch 173/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1472 - reconstruction_loss: 36.7980 - total loss: 42.9452 - val_total loss: 47.9915 - val_reconstruction_loss: 41.9512 - val_kl_loss: 6.0403
# Epoch 174/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1607 - reconstruction_loss: 37.2454 - total loss: 43.4061 - val_total loss: 47.9469 - val_reconstruction_loss: 41.9189 - val_kl_loss: 6.0280
# Epoch 175/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1519 - reconstruction_loss: 37.1928 - total loss: 43.3447 - val_total loss: 47.9045 - val_reconstruction_loss: 41.8702 - val_kl_loss: 6.0343
# Epoch 176/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1493 - reconstruction_loss: 36.9039 - total loss: 43.0532 - val_total loss: 47.9719 - val_reconstruction_loss: 41.9458 - val_kl_loss: 6.0260
# Epoch 177/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1530 - reconstruction_loss: 36.7556 - total loss: 42.9086 - val_total loss: 47.9654 - val_reconstruction_loss: 41.9283 - val_kl_loss: 6.0371
# Epoch 178/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1508 - reconstruction_loss: 36.8227 - total loss: 42.9735 - val_total loss: 47.8699 - val_reconstruction_loss: 41.8357 - val_kl_loss: 6.0343
# Epoch 179/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1602 - reconstruction_loss: 36.8193 - total loss: 42.9795 - val_total loss: 47.8837 - val_reconstruction_loss: 41.8612 - val_kl_loss: 6.0225
# Epoch 180/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1472 - reconstruction_loss: 37.0922 - total loss: 43.2394 - val_total loss: 47.8969 - val_reconstruction_loss: 41.8649 - val_kl_loss: 6.0320
# Epoch 181/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1513 - reconstruction_loss: 36.8608 - total loss: 43.0121 - val_total loss: 47.9435 - val_reconstruction_loss: 41.9160 - val_kl_loss: 6.0274
# Epoch 182/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1460 - reconstruction_loss: 36.9287 - total loss: 43.0747 - val_total loss: 47.9668 - val_reconstruction_loss: 41.9264 - val_kl_loss: 6.0404
# Epoch 183/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1595 - reconstruction_loss: 37.1992 - total loss: 43.3587 - val_total loss: 47.9464 - val_reconstruction_loss: 41.9135 - val_kl_loss: 6.0328
# Epoch 184/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1584 - reconstruction_loss: 37.0392 - total loss: 43.1975 - val_total loss: 47.9348 - val_reconstruction_loss: 41.8939 - val_kl_loss: 6.0409
# Epoch 185/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1600 - reconstruction_loss: 37.0969 - total loss: 43.2569 - val_total loss: 47.9646 - val_reconstruction_loss: 41.9310 - val_kl_loss: 6.0336
# Epoch 186/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1623 - reconstruction_loss: 36.9921 - total loss: 43.1544 - val_total loss: 47.8906 - val_reconstruction_loss: 41.8474 - val_kl_loss: 6.0433
# Epoch 187/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1641 - reconstruction_loss: 37.0093 - total loss: 43.1735 - val_total loss: 47.8907 - val_reconstruction_loss: 41.8474 - val_kl_loss: 6.0434
# Epoch 188/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1583 - reconstruction_loss: 36.7322 - total loss: 42.8905 - val_total loss: 47.8726 - val_reconstruction_loss: 41.8386 - val_kl_loss: 6.0341
# Epoch 189/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1526 - reconstruction_loss: 36.8028 - total loss: 42.9554 - val_total loss: 47.8767 - val_reconstruction_loss: 41.8472 - val_kl_loss: 6.0295
# Epoch 190/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1607 - reconstruction_loss: 36.8686 - total loss: 43.0294 - val_total loss: 47.9274 - val_reconstruction_loss: 41.8937 - val_kl_loss: 6.0337
# Epoch 191/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 6.1547 - reconstruction_loss: 36.8508 - total loss: 43.0055 - val_total loss: 47.9834 - val_reconstruction_loss: 41.9465 - val_kl_loss: 6.0368
# Epoch 192/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1626 - reconstruction_loss: 37.0089 - total loss: 43.1715 - val_total loss: 47.9050 - val_reconstruction_loss: 41.8641 - val_kl_loss: 6.0409
# Epoch 193/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1600 - reconstruction_loss: 36.9392 - total loss: 43.0992 - val_total loss: 48.0115 - val_reconstruction_loss: 41.9795 - val_kl_loss: 6.0320
# Epoch 194/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1623 - reconstruction_loss: 37.0857 - total loss: 43.2480 - val_total loss: 47.8444 - val_reconstruction_loss: 41.8083 - val_kl_loss: 6.0361
# Epoch 195/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1524 - reconstruction_loss: 36.9978 - total loss: 43.1502 - val_total loss: 47.8719 - val_reconstruction_loss: 41.8349 - val_kl_loss: 6.0370
# Epoch 196/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1571 - reconstruction_loss: 37.0437 - total loss: 43.2008 - val_total loss: 47.9628 - val_reconstruction_loss: 41.9253 - val_kl_loss: 6.0375
# Epoch 197/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1552 - reconstruction_loss: 37.0157 - total loss: 43.1709 - val_total loss: 47.9026 - val_reconstruction_loss: 41.8627 - val_kl_loss: 6.0399
# Epoch 198/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1526 - reconstruction_loss: 36.6818 - total loss: 42.8344 - val_total loss: 47.8548 - val_reconstruction_loss: 41.8180 - val_kl_loss: 6.0369
# Epoch 199/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1704 - reconstruction_loss: 37.1887 - total loss: 43.3591 - val_total loss: 48.0094 - val_reconstruction_loss: 41.9727 - val_kl_loss: 6.0366
# Epoch 200/5000
# 442/449 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_loss: 6.1621 - reconstruction_loss: 36.9524 - total loss: 43.1145Checkpoint saved at epoch 200
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1619 - reconstruction_loss: 36.9505 - total loss: 43.1124 - val_total loss: 47.9352 - val_reconstruction_loss: 41.8985 - val_kl_loss: 6.0367
# Epoch 201/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1495 - reconstruction_loss: 36.8443 - total loss: 42.9938 - val_total loss: 47.9130 - val_reconstruction_loss: 41.8777 - val_kl_loss: 6.0353
# Epoch 202/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1590 - reconstruction_loss: 36.9783 - total loss: 43.1374 - val_total loss: 47.9059 - val_reconstruction_loss: 41.8725 - val_kl_loss: 6.0335
# Epoch 203/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1626 - reconstruction_loss: 37.2089 - total loss: 43.3715 - val_total loss: 47.9122 - val_reconstruction_loss: 41.8734 - val_kl_loss: 6.0388
# Epoch 204/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1569 - reconstruction_loss: 36.9281 - total loss: 43.0849 - val_total loss: 47.9787 - val_reconstruction_loss: 41.9345 - val_kl_loss: 6.0441
# Epoch 205/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1636 - reconstruction_loss: 36.7745 - total loss: 42.9381 - val_total loss: 47.8867 - val_reconstruction_loss: 41.8409 - val_kl_loss: 6.0459
# Epoch 206/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1682 - reconstruction_loss: 36.9645 - total loss: 43.1327 - val_total loss: 47.9143 - val_reconstruction_loss: 41.8729 - val_kl_loss: 6.0415
# Epoch 207/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1597 - reconstruction_loss: 37.1356 - total loss: 43.2953 - val_total loss: 47.9069 - val_reconstruction_loss: 41.8638 - val_kl_loss: 6.0431
# Epoch 208/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1580 - reconstruction_loss: 36.9964 - total loss: 43.1544 - val_total loss: 47.9026 - val_reconstruction_loss: 41.8600 - val_kl_loss: 6.0426
# Epoch 209/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1656 - reconstruction_loss: 36.7589 - total loss: 42.9245 - val_total loss: 47.9307 - val_reconstruction_loss: 41.8900 - val_kl_loss: 6.0406
# Epoch 210/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1652 - reconstruction_loss: 36.6010 - total loss: 42.7662 - val_total loss: 47.9010 - val_reconstruction_loss: 41.8606 - val_kl_loss: 6.0404
# Epoch 211/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1566 - reconstruction_loss: 36.8137 - total loss: 42.9703 - val_total loss: 47.8706 - val_reconstruction_loss: 41.8309 - val_kl_loss: 6.0397
# Epoch 212/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1694 - reconstruction_loss: 36.8968 - total loss: 43.0662 - val_total loss: 47.8937 - val_reconstruction_loss: 41.8526 - val_kl_loss: 6.0410
# Epoch 213/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1561 - reconstruction_loss: 36.7796 - total loss: 42.9357 - val_total loss: 47.9397 - val_reconstruction_loss: 41.9011 - val_kl_loss: 6.0386
# Epoch 214/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1614 - reconstruction_loss: 36.6112 - total loss: 42.7726 - val_total loss: 47.8537 - val_reconstruction_loss: 41.8144 - val_kl_loss: 6.0393
# Epoch 215/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1585 - reconstruction_loss: 37.0107 - total loss: 43.1691 - val_total loss: 47.9006 - val_reconstruction_loss: 41.8603 - val_kl_loss: 6.0402
# Epoch 216/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1665 - reconstruction_loss: 36.9047 - total loss: 43.0711 - val_total loss: 47.9242 - val_reconstruction_loss: 41.8839 - val_kl_loss: 6.0403
# Epoch 217/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1542 - reconstruction_loss: 36.9374 - total loss: 43.0915 - val_total loss: 47.9076 - val_reconstruction_loss: 41.8674 - val_kl_loss: 6.0402
# Epoch 218/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1522 - reconstruction_loss: 36.6723 - total loss: 42.8245 - val_total loss: 47.9470 - val_reconstruction_loss: 41.9065 - val_kl_loss: 6.0404
# Epoch 219/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1581 - reconstruction_loss: 36.7484 - total loss: 42.9065 - val_total loss: 47.8763 - val_reconstruction_loss: 41.8358 - val_kl_loss: 6.0405
# Epoch 220/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1628 - reconstruction_loss: 36.8803 - total loss: 43.0431 - val_total loss: 47.8914 - val_reconstruction_loss: 41.8508 - val_kl_loss: 6.0406
# Epoch 221/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1617 - reconstruction_loss: 36.9404 - total loss: 43.1021 - val_total loss: 47.9304 - val_reconstruction_loss: 41.8898 - val_kl_loss: 6.0406
# Epoch 222/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1562 - reconstruction_loss: 36.8029 - total loss: 42.9590 - val_total loss: 47.9058 - val_reconstruction_loss: 41.8652 - val_kl_loss: 6.0406
# Epoch 223/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1581 - reconstruction_loss: 36.8990 - total loss: 43.0571 - val_total loss: 47.8732 - val_reconstruction_loss: 41.8327 - val_kl_loss: 6.0406
# Epoch 224/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1607 - reconstruction_loss: 36.8822 - total loss: 43.0428 - val_total loss: 47.9292 - val_reconstruction_loss: 41.8886 - val_kl_loss: 6.0406
# Epoch 225/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1577 - reconstruction_loss: 36.7211 - total loss: 42.8788 - val_total loss: 47.8966 - val_reconstruction_loss: 41.8560 - val_kl_loss: 6.0406
# Epoch 226/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1590 - reconstruction_loss: 36.8181 - total loss: 42.9770 - val_total loss: 47.9325 - val_reconstruction_loss: 41.8920 - val_kl_loss: 6.0406
# Epoch 227/5000
# ...
# Epoch 4927/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1573 - reconstruction_loss: 36.7624 - total loss: 42.9198 - val_total loss: 47.8827 - val_reconstruction_loss: 41.8421 - val_kl_loss: 6.0406
# Epoch 4928/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1590 - reconstruction_loss: 36.7398 - total loss: 42.8988 - val_total loss: 47.8614 - val_reconstruction_loss: 41.8209 - val_kl_loss: 6.0406
# Epoch 4929/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1694 - reconstruction_loss: 36.8536 - total loss: 43.0230 - val_total loss: 47.8892 - val_reconstruction_loss: 41.8486 - val_kl_loss: 6.0406
# Epoch 4930/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1573 - reconstruction_loss: 36.9349 - total loss: 43.0923 - val_total loss: 47.9254 - val_reconstruction_loss: 41.8848 - val_kl_loss: 6.0406
# Epoch 4931/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1677 - reconstruction_loss: 36.9470 - total loss: 43.1147 - val_total loss: 47.9224 - val_reconstruction_loss: 41.8818 - val_kl_loss: 6.0406
# Epoch 4932/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1586 - reconstruction_loss: 36.7834 - total loss: 42.9420 - val_total loss: 47.9439 - val_reconstruction_loss: 41.9034 - val_kl_loss: 6.0406
# Epoch 4933/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1537 - reconstruction_loss: 37.1372 - total loss: 43.2909 - val_total loss: 47.9167 - val_reconstruction_loss: 41.8762 - val_kl_loss: 6.0406
# Epoch 4934/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1558 - reconstruction_loss: 36.5121 - total loss: 42.6679 - val_total loss: 47.8969 - val_reconstruction_loss: 41.8563 - val_kl_loss: 6.0406
# Epoch 4935/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1645 - reconstruction_loss: 36.9720 - total loss: 43.1365 - val_total loss: 47.8424 - val_reconstruction_loss: 41.8018 - val_kl_loss: 6.0406
# Epoch 4936/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1545 - reconstruction_loss: 36.9495 - total loss: 43.1039 - val_total loss: 47.9460 - val_reconstruction_loss: 41.9054 - val_kl_loss: 6.0406
# Epoch 4937/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1592 - reconstruction_loss: 36.9005 - total loss: 43.0597 - val_total loss: 47.8857 - val_reconstruction_loss: 41.8452 - val_kl_loss: 6.0406
# Epoch 4938/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1627 - reconstruction_loss: 36.8213 - total loss: 42.9840 - val_total loss: 47.9280 - val_reconstruction_loss: 41.8875 - val_kl_loss: 6.0406
# Epoch 4939/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1647 - reconstruction_loss: 36.6719 - total loss: 42.8366 - val_total loss: 47.9653 - val_reconstruction_loss: 41.9247 - val_kl_loss: 6.0406
# Epoch 4940/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1642 - reconstruction_loss: 36.9592 - total loss: 43.1234 - val_total loss: 47.9215 - val_reconstruction_loss: 41.8809 - val_kl_loss: 6.0406
# Epoch 4941/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1572 - reconstruction_loss: 36.7823 - total loss: 42.9395 - val_total loss: 47.9515 - val_reconstruction_loss: 41.9109 - val_kl_loss: 6.0406
# Epoch 4942/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1579 - reconstruction_loss: 36.7143 - total loss: 42.8722 - val_total loss: 47.9442 - val_reconstruction_loss: 41.9036 - val_kl_loss: 6.0406
# Epoch 4943/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1625 - reconstruction_loss: 36.9691 - total loss: 43.1316 - val_total loss: 47.8877 - val_reconstruction_loss: 41.8471 - val_kl_loss: 6.0406
# Epoch 4944/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1619 - reconstruction_loss: 36.9371 - total loss: 43.0990 - val_total loss: 47.8896 - val_reconstruction_loss: 41.8490 - val_kl_loss: 6.0406
# Epoch 4945/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1645 - reconstruction_loss: 37.0832 - total loss: 43.2477 - val_total loss: 47.9570 - val_reconstruction_loss: 41.9164 - val_kl_loss: 6.0406
# Epoch 4946/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1563 - reconstruction_loss: 36.6011 - total loss: 42.7574 - val_total loss: 47.8920 - val_reconstruction_loss: 41.8514 - val_kl_loss: 6.0406
# Epoch 4947/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1585 - reconstruction_loss: 36.8968 - total loss: 43.0553 - val_total loss: 47.9246 - val_reconstruction_loss: 41.8840 - val_kl_loss: 6.0406
# Epoch 4948/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1571 - reconstruction_loss: 36.7650 - total loss: 42.9221 - val_total loss: 47.9025 - val_reconstruction_loss: 41.8619 - val_kl_loss: 6.0406
# Epoch 4949/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1522 - reconstruction_loss: 36.8309 - total loss: 42.9831 - val_total loss: 47.9179 - val_reconstruction_loss: 41.8773 - val_kl_loss: 6.0406
# Epoch 4950/5000
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_loss: 6.1660 - reconstruction_loss: 36.9173 - total loss: 43.0832Checkpoint saved at epoch 4950
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1659 - reconstruction_loss: 36.9165 - total loss: 43.0824 - val_total loss: 47.9098 - val_reconstruction_loss: 41.8692 - val_kl_loss: 6.0406
# Epoch 4951/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1610 - reconstruction_loss: 36.6280 - total loss: 42.7890 - val_total loss: 47.8964 - val_reconstruction_loss: 41.8558 - val_kl_loss: 6.0406
# Epoch 4952/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1610 - reconstruction_loss: 36.7899 - total loss: 42.9509 - val_total loss: 47.9178 - val_reconstruction_loss: 41.8773 - val_kl_loss: 6.0406
# Epoch 4953/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1625 - reconstruction_loss: 36.7698 - total loss: 42.9323 - val_total loss: 47.9564 - val_reconstruction_loss: 41.9158 - val_kl_loss: 6.0406
# Epoch 4954/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1538 - reconstruction_loss: 36.7205 - total loss: 42.8743 - val_total loss: 47.9198 - val_reconstruction_loss: 41.8792 - val_kl_loss: 6.0406
# Epoch 4955/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1643 - reconstruction_loss: 36.9347 - total loss: 43.0990 - val_total loss: 47.9084 - val_reconstruction_loss: 41.8678 - val_kl_loss: 6.0406
# Epoch 4956/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1524 - reconstruction_loss: 36.6557 - total loss: 42.8080 - val_total loss: 47.9041 - val_reconstruction_loss: 41.8636 - val_kl_loss: 6.0406
# Epoch 4957/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1622 - reconstruction_loss: 36.9483 - total loss: 43.1105 - val_total loss: 47.9349 - val_reconstruction_loss: 41.8943 - val_kl_loss: 6.0406
# Epoch 4958/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1582 - reconstruction_loss: 36.6430 - total loss: 42.8012 - val_total loss: 47.8693 - val_reconstruction_loss: 41.8287 - val_kl_loss: 6.0406
# Epoch 4959/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1481 - reconstruction_loss: 37.1489 - total loss: 43.2970 - val_total loss: 47.9349 - val_reconstruction_loss: 41.8944 - val_kl_loss: 6.0406
# Epoch 4960/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1488 - reconstruction_loss: 36.4873 - total loss: 42.6361 - val_total loss: 47.9154 - val_reconstruction_loss: 41.8748 - val_kl_loss: 6.0406
# Epoch 4961/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1604 - reconstruction_loss: 36.8894 - total loss: 43.0498 - val_total loss: 47.8887 - val_reconstruction_loss: 41.8481 - val_kl_loss: 6.0406
# Epoch 4962/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1584 - reconstruction_loss: 36.8040 - total loss: 42.9624 - val_total loss: 47.8812 - val_reconstruction_loss: 41.8406 - val_kl_loss: 6.0406
# Epoch 4963/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1583 - reconstruction_loss: 36.9851 - total loss: 43.1434 - val_total loss: 47.9020 - val_reconstruction_loss: 41.8614 - val_kl_loss: 6.0406
# Epoch 4964/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1606 - reconstruction_loss: 36.6253 - total loss: 42.7859 - val_total loss: 47.9159 - val_reconstruction_loss: 41.8753 - val_kl_loss: 6.0406
# Epoch 4965/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1626 - reconstruction_loss: 36.8433 - total loss: 43.0058 - val_total loss: 47.8905 - val_reconstruction_loss: 41.8499 - val_kl_loss: 6.0406
# Epoch 4966/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1597 - reconstruction_loss: 36.7020 - total loss: 42.8617 - val_total loss: 47.8951 - val_reconstruction_loss: 41.8546 - val_kl_loss: 6.0406
# Epoch 4967/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1570 - reconstruction_loss: 36.8393 - total loss: 42.9963 - val_total loss: 47.9608 - val_reconstruction_loss: 41.9203 - val_kl_loss: 6.0406
# Epoch 4968/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1648 - reconstruction_loss: 36.7562 - total loss: 42.9209 - val_total loss: 47.8988 - val_reconstruction_loss: 41.8582 - val_kl_loss: 6.0406
# Epoch 4969/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1590 - reconstruction_loss: 36.8046 - total loss: 42.9637 - val_total loss: 47.9166 - val_reconstruction_loss: 41.8760 - val_kl_loss: 6.0406
# Epoch 4970/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1611 - reconstruction_loss: 36.8034 - total loss: 42.9645 - val_total loss: 47.8909 - val_reconstruction_loss: 41.8503 - val_kl_loss: 6.0406
# Epoch 4971/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1564 - reconstruction_loss: 36.6378 - total loss: 42.7942 - val_total loss: 47.9718 - val_reconstruction_loss: 41.9312 - val_kl_loss: 6.0406
# Epoch 4972/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1603 - reconstruction_loss: 36.8561 - total loss: 43.0163 - val_total loss: 47.9443 - val_reconstruction_loss: 41.9037 - val_kl_loss: 6.0406
# Epoch 4973/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1550 - reconstruction_loss: 36.7478 - total loss: 42.9028 - val_total loss: 47.8986 - val_reconstruction_loss: 41.8580 - val_kl_loss: 6.0406
# Epoch 4974/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1507 - reconstruction_loss: 37.0424 - total loss: 43.1931 - val_total loss: 47.9139 - val_reconstruction_loss: 41.8733 - val_kl_loss: 6.0406
# Epoch 4975/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1612 - reconstruction_loss: 36.7522 - total loss: 42.9134 - val_total loss: 47.9077 - val_reconstruction_loss: 41.8672 - val_kl_loss: 6.0406
# Epoch 4976/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1580 - reconstruction_loss: 36.8146 - total loss: 42.9727 - val_total loss: 47.9132 - val_reconstruction_loss: 41.8726 - val_kl_loss: 6.0406
# Epoch 4977/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1562 - reconstruction_loss: 37.1340 - total loss: 43.2902 - val_total loss: 47.8795 - val_reconstruction_loss: 41.8389 - val_kl_loss: 6.0406
# Epoch 4978/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1568 - reconstruction_loss: 36.8274 - total loss: 42.9841 - val_total loss: 47.9043 - val_reconstruction_loss: 41.8637 - val_kl_loss: 6.0406
# Epoch 4979/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1567 - reconstruction_loss: 36.8458 - total loss: 43.0025 - val_total loss: 47.9221 - val_reconstruction_loss: 41.8816 - val_kl_loss: 6.0406
# Epoch 4980/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1605 - reconstruction_loss: 36.7877 - total loss: 42.9482 - val_total loss: 47.8833 - val_reconstruction_loss: 41.8428 - val_kl_loss: 6.0406
# Epoch 4981/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1585 - reconstruction_loss: 36.5024 - total loss: 42.6609 - val_total loss: 47.8935 - val_reconstruction_loss: 41.8530 - val_kl_loss: 6.0406
# Epoch 4982/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1586 - reconstruction_loss: 36.6401 - total loss: 42.7987 - val_total loss: 47.9441 - val_reconstruction_loss: 41.9036 - val_kl_loss: 6.0406
# Epoch 4983/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1610 - reconstruction_loss: 36.7281 - total loss: 42.8891 - val_total loss: 47.8808 - val_reconstruction_loss: 41.8402 - val_kl_loss: 6.0406
# Epoch 4984/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1645 - reconstruction_loss: 36.8732 - total loss: 43.0377 - val_total loss: 47.9246 - val_reconstruction_loss: 41.8840 - val_kl_loss: 6.0406
# Epoch 4985/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1565 - reconstruction_loss: 36.7287 - total loss: 42.8852 - val_total loss: 47.8647 - val_reconstruction_loss: 41.8241 - val_kl_loss: 6.0406
# Epoch 4986/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1567 - reconstruction_loss: 36.9005 - total loss: 43.0572 - val_total loss: 47.9389 - val_reconstruction_loss: 41.8984 - val_kl_loss: 6.0406
# Epoch 4987/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1627 - reconstruction_loss: 36.7380 - total loss: 42.9007 - val_total loss: 47.9280 - val_reconstruction_loss: 41.8875 - val_kl_loss: 6.0406
# Epoch 4988/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1533 - reconstruction_loss: 36.9990 - total loss: 43.1523 - val_total loss: 47.9528 - val_reconstruction_loss: 41.9122 - val_kl_loss: 6.0406
# Epoch 4989/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1591 - reconstruction_loss: 36.9374 - total loss: 43.0965 - val_total loss: 47.9140 - val_reconstruction_loss: 41.8735 - val_kl_loss: 6.0406
# Epoch 4990/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1695 - reconstruction_loss: 36.9313 - total loss: 43.1008 - val_total loss: 47.8905 - val_reconstruction_loss: 41.8499 - val_kl_loss: 6.0406
# Epoch 4991/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1489 - reconstruction_loss: 36.6300 - total loss: 42.7789 - val_total loss: 47.9405 - val_reconstruction_loss: 41.8999 - val_kl_loss: 6.0406
# Epoch 4992/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1634 - reconstruction_loss: 37.0362 - total loss: 43.1996 - val_total loss: 47.9300 - val_reconstruction_loss: 41.8894 - val_kl_loss: 6.0406
# Epoch 4993/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1562 - reconstruction_loss: 36.7867 - total loss: 42.9429 - val_total loss: 47.9334 - val_reconstruction_loss: 41.8928 - val_kl_loss: 6.0406
# Epoch 4994/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1661 - reconstruction_loss: 37.0349 - total loss: 43.2010 - val_total loss: 47.9511 - val_reconstruction_loss: 41.9105 - val_kl_loss: 6.0406
# Epoch 4995/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1517 - reconstruction_loss: 36.6449 - total loss: 42.7966 - val_total loss: 47.8989 - val_reconstruction_loss: 41.8583 - val_kl_loss: 6.0406
# Epoch 4996/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1583 - reconstruction_loss: 36.7310 - total loss: 42.8893 - val_total loss: 47.8832 - val_reconstruction_loss: 41.8426 - val_kl_loss: 6.0406
# Epoch 4997/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1555 - reconstruction_loss: 37.0063 - total loss: 43.1617 - val_total loss: 47.8901 - val_reconstruction_loss: 41.8496 - val_kl_loss: 6.0406
# Epoch 4998/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1652 - reconstruction_loss: 37.0097 - total loss: 43.1749 - val_total loss: 47.9249 - val_reconstruction_loss: 41.8843 - val_kl_loss: 6.0406
# Epoch 4999/5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.1630 - reconstruction_loss: 36.8594 - total loss: 43.0224 - val_total loss: 47.8870 - val_reconstruction_loss: 41.8464 - val_kl_loss: 6.0406
# Epoch 5000/5000
# 441/449 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_loss: 6.1612 - reconstruction_loss: 37.1257 - total loss: 43.2869Checkpoint saved at epoch 5000
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - kl_loss: 6.1611 - reconstruction_loss: 37.1198 - total loss: 43.2810 - val_total loss: 47.9258 - val_reconstruction_loss: 41.8853 - val_kl_loss: 6.0406

# %% [markdown]
# save:

# %%
# # save the model?
# encoder.save('encoder_naive_vae.keras', overwrite=True)#, save_format='tf')
# decoder.save('decoder_naive_vae.keras', overwrite=True)#, save_format='tf')
# # save the history as well
# # Save history object
# with open('naive_vae_history.pkl', 'wb') as f:
#     pickle.dump(history.history, f)

# %% [markdown]
# Load encoder, decoder and history:

# %%
keras.utils.get_custom_objects().update({
    "Sampling": Sampling,
})

encoder = tf.keras.models.load_model('encoder_naive_vae.keras')
decoder = tf.keras.models.load_model('decoder_naive_vae.keras')

with open('naive_vae_history.pkl', 'rb') as f:
    history = pickle.load(f)

len(history['total loss'])
# Out:
# 5000

# %%
# plt.ylim(4.5, 7.)
# plt.plot(history['reconstruction_loss'])
# plt.plot(history['kl loss'])
plt.plot(history['total loss'], linewidth=2.5, color='dodgerblue', label = 'Training')
plt.plot(history['val_total loss'], linewidth=2.5, color='darkorange', label = 'Test')
plt.xlim(0, 300)
plt.xlabel('Epoch'), plt.ylabel('Loss')
plt.legend()

# %%
testmean, testvar, testz = encoder(standardized_abundance_test_arr)
test_reconstruction = decoder(testz)
standardized_abundance_test_arr, test_reconstruction
# Out:
# (array([[ 0.26717617,  0.58071564,  0.77119327, ...,  0.07171473,
#           0.17625654,  0.18141452],
#         [ 1.30125899, -0.6162556 , -1.75398675, ...,  1.32887713,
#           0.47415769,  0.63605213],
#         [ 0.2016009 , -0.34355209, -0.19853193, ..., -0.18691169,
#           0.12079571, -0.44497627],
#         ...,
#         [-0.76002689, -0.58530829, -0.48424128, ..., -0.14240413,
#           0.42637037, -0.7731237 ],
#         [-0.36292976,  0.29027586,  0.34492908, ...,  0.28826048,
#           0.58893306, -0.40693741],
#         [ 0.97252638, -2.01160426, -2.7254828 , ...,  0.1629832 ,
#          -0.81646843, -1.6595545 ]]),
#  <tf.Tensor: shape=(14374, 19), dtype=float32, numpy=
#  array([[ 0.51576984,  0.54499257,  0.3645685 , ...,  0.14337827,
#           0.33631483, -0.1448647 ],
#         [ 1.5262707 , -0.20216486, -0.6281298 , ...,  1.7993065 ,
#           0.5643227 ,  0.27411342],
#         [-0.18776974, -0.4082334 , -0.41644672, ...,  0.26188582,
#           0.27053088, -0.41775784],
#         ...,
#         [-0.5795087 , -0.50152266, -0.39589202, ...,  0.11291428,
#           0.29318047, -0.16195801],
#         [-0.35289192, -0.03673042,  0.03106556, ...,  0.08888112,
#           0.331465  , -0.11981067],
#         [ 0.6446848 , -1.1999189 , -1.3838403 , ...,  0.42202076,
#          -0.53215337, -1.5563009 ]], dtype=float32)>)

# %%
# mses = (test_reconstruction - standardized_abundance_test_arr)[:,0]

plt.figure(figsize = (12, 6))
plt.scatter(standardized_abundance_test_arr[:,0], test_reconstruction[:,0], s=0.2)
# plt.ylim(bottom=0., top=0.1)

# %%
ind = 5  # 19 parameters, 0 to 18
samp_rate = 1

plt.figure(figsize = (12, 6))
plt.scatter(standardized_abundance_test_arr[:,ind][::samp_rate], test_reconstruction[:,ind][::samp_rate], s=0.1)#, xerr=np.exp(standardized_abundance_test_arr[:,ind+19][::samp_rate]/2), yerr=np.exp(test_reconstruction[:,ind+19][::samp_rate]/2), fmt='.', markersize=5, elinewidth=0.5)
# plt.plot(np.linspace(0., 0.3, int(1e4)), np.linspace(0., 0.3, int(1e4)), c='r')
plt.plot(np.linspace(np.min(standardized_abundance_test_arr[:,ind]), np.max(standardized_abundance_test_arr[:,ind]), int(1e5)), np.linspace(np.min(standardized_abundance_test_arr[:,ind]), np.max(standardized_abundance_test_arr[:,ind]), int(1e5)), c='r')
plt.xlabel('Original'), plt.ylabel('Reconstructed')
# plt.xlim(-0.5, 0.4)
# plt.ylim(-0.5, 0.4)
# Out:
# (Text(0.5, 0, 'Original'), Text(0, 0.5, 'Reconstructed'))

# %%
import matplotlib as mpl
plt.rc('font', size=18)

ind=0

fig = plt.figure(figsize = (14, 8))
# ax = fig.add_subplot(111)    # The big subplot
ax0 = fig.add_subplot(221)
ax1 = fig.add_subplot(222)
# ax2 = fig.add_subplot(223)
# ax3 = fig.add_subplot(224)
# plot the metallicity
ax0.scatter(standardized_abundance_test_arr[:,ind], test_reconstruction[:,ind], s=0.1)
ax0.plot(np.linspace(np.min(standardized_abundance_test_arr[:,ind]), np.max(standardized_abundance_test_arr[:,ind]), int(1e5)), np.linspace(np.min(standardized_abundance_test_arr[:,ind]), np.max(standardized_abundance_test_arr[:,ind]), int(1e5)), c='r')
ax0.set_xlabel('Fe/H'), ax0.set_ylabel('Reconstructed')
# plot the residuals of metallicity
# ax1.hist2d(standardized_abundance_test_arr[:,ind], standardized_abundance_test_arr[:,ind] - test_reconstruction[:,ind], norm=mpl.colors.LogNorm(), bins=200)
ax1.scatter(standardized_abundance_test_arr[:,ind], standardized_abundance_test_arr[:,ind] - test_reconstruction[:,ind], s=0.1)
ax1.set_xlabel(r'Fe/H'), ax1.set_ylabel('Residual')
# ax1.scatter(standardized_abundance_test_arr[:,ind], standardized_abundance_test_arr[:,ind] - test_reconstruction[:,ind], s=0.1)
ax1.axhline(0, c='r')
plt.tight_layout()
plt.savefig('metallicity_original_vs_reconstructed_naive.png')

# %%
np.std(standardized_abundance_test_arr[:,ind] - test_reconstruction[:,ind])
# Out:
# 0.32155687

# %% [markdown]
# Plot:

# %%
abundances = ['Fe/H', 'C/Fe', 'Ci/Fe', 'N/Fe', 'O/Fe', 'Mg/Fe', 'Al/Fe', 'Si/Fe', 'P/Fe', 'S/Fe', 'K/Fe', 'Ca/Fe', 'Ti/Fe', 'Tiii/Fe', 'V/Fe', 'Cr/Fe', 'Mn/Fe', 'Co/Fe', 'Ni/Fe']
divisor = 4  # fraction of the range to scale the plots by

plt.rc('font', size=14)
fig, ax = plt.subplots(6, 3, figsize=(14, 14))
for i in range(6):
    for j in range(3):
        ax[i, j].scatter(standardized_abundance_test_arr[:,3*i+j+1][::samp_rate], test_reconstruction[:,3*i+j+1][::samp_rate], s=0.1)
        # plt.plot(np.linspace(0., 0.3, int(1e4)), np.linspace(0., 0.3, int(1e4)), c='r')
        ax[i, j].plot(np.linspace(np.min(standardized_abundance_test_arr[:,3*i+j+1]), np.max(standardized_abundance_test_arr[:,3*i+j+1]), int(1e5)), 
                      np.linspace(np.min(standardized_abundance_test_arr[:,3*i+j+1]), np.max(standardized_abundance_test_arr[:,3*i+j+1]), int(1e5)), c='r')
        ax[i, j].set_xlabel(abundances[3*i+j+1])# , ax[i, j].set_ylabel('Reconstructed')       
        # scale it properly based on reconstruction
        abundance_min, abundance_max = np.quantile(standardized_abundance_test_arr[:,3*i+j+1], (0.005, 0.995))
        # abundance_min = np.min(test_reconstruction[:, 3*i + j])
        # abundance_max = np.max(test_reconstruction[:, 3*i + j])
        diff = np.abs(abundance_max - abundance_min)
        # scale it
        ax[i, j].set_xlim(abundance_min - diff/divisor, abundance_max + diff/divisor) 
        ax[i, j].set_ylim(abundance_min - diff/divisor, abundance_max + diff/divisor) 
        
plt.tight_layout()
plt.savefig('original_vs_reconstructed_naive_all.png')# , fmt='png')
plt.show()

# %%
plt.scatter(standardized_abundance_test_arr[:,17], (standardized_abundance_test_arr[:,17] - test_reconstruction[:, 17]), s=0.1)
